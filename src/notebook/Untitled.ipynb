# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from glob import glob
from skimage import io
from pathlib import Path
from joblib import load

# %%
rfp_classifier = '/home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie/neck_classifier.joblib'
gfp_classifier = ''

# %%
load(rfp_classifier)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 load(rfp_classifier)
#
# File ~/anaconda3/envs/cuttlefish/lib/python3.9/site-packages/joblib/numpy_pickle.py:658, in load(filename, mmap_mode)
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#     656                 return load_compatibility(fobj)
# --> 658             obj = _unpickle(fobj, filename, mmap_mode)
#     659 return obj
#
# File ~/anaconda3/envs/cuttlefish/lib/python3.9/site-packages/joblib/numpy_pickle.py:577, in _unpickle(fobj, filename, mmap_mode)
#     575 obj = None
#     576 try:
# --> 577     obj = unpickler.load()
# ...

# %%
for p, dirnames, filenames in os.walk('/home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie'):
    if 'rfp' in dirnames:
        in_path = os.path.join(p, 'rfp')
        out_path = os.path.join(p, 'rfp_classified')
        # print(glob(in_path + '/*.tif'))
        print(out_path)
# Out:
# /home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie/20250417_clb2_snapshots/processed/yet1057_rep_2/position_07/z_level_0/rfp_classified
# /home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie/20250417_clb2_snapshots/processed/yet1057_rep_2/position_18/z_level_0/rfp_classified
# /home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie/20250417_clb2_snapshots/processed/yet1057_rep_2/position_19/z_level_0/rfp_classified
# /home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie/20250417_clb2_snapshots/processed/yet1057_rep_2/position_17/z_level_0/rfp_classified
# /home/philipp/PycharmProjects/experiments/clb2_data_processing_resubmission/data_lacie/20250417_clb2_snapshots/processed/yet1057_rep_2/position_00/z_level_0/rfp_classified
# ...
