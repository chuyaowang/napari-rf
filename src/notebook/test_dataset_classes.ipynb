# %%
import sys
sys.path.append('../')
from napari_rf.datasets.datasets import get_dataset
import matplotlib.pyplot as plt

# %%
cfg = {'dataset':'/media/philipp/toshiba/20250417_clb2_snapshots/processed',
      'dataset_path':'/media/philipp/toshiba/20250417_clb2_snapshots',
      'channels_to_segment':'rfp',
      'positions':list(range(20)),
      'frames':0, 'z_levels':0, 'normalise_img':False}
data = get_dataset(cfg)
# Out:
# opening folders

# %%
for a in data:
    plt.imshow(a[0])
    plt.show()
    break

# %%
print(a[1])
# Out:
# position_0/z_level_0/channel_0/frame_0.tif

# %%
data.fills
# Out:
# {'m': 2, 'z': 1, 't': 1, 'c': 1}
